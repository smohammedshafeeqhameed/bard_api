# %%
pip install bardapi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install gTTs
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install git+https://github.com/dsdanielpark/Bard-API.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/dsdanielpark/Bard-API.git to /tmp/pip-req-build-26czvwgy
#   Running command git clone --filter=blob:none --quiet https://github.com/dsdanielpark/Bard-API.git /tmp/pip-req-build-26czvwgy
#   Resolved https://github.com/dsdanielpark/Bard-API.git to commit fa94159051b06d7d8ad9323ebaf82948f3c78789
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.1 MB/s eta 0:00:00
# ...
#   Created wheel for bardapi: filename=bardapi-0.1.16-py3-none-any.whl size=17561 sha256=221d99745709818878319b05fea1fa5917e6c2f2c6549db273f670f340329bee
# ...

# %%
from bardapi import Bard

token = 'TOKEN_FROM_BARD'
bard = Bard(token=token)
bard.get_answer("Hi Good Morning")['content']
# Out:
# 'Hi! Good morning to you too! How can I help you today?'

# %%
bard.get_answer("Hi Good Morning")
# Out:
# {'content': 'Hello there!\r\n\r\nHow can I help you on this fine morning?',
#  'conversation_id': 'c_9760479c5d8a9a3d',
#  'response_id': 'r_e5a9f187a079c2b8',
#  'factualityQueries': [],
#  'textQuery': ['Google Developer Groups', 1],
#  'choices': [{'id': 'rc_e5a9f187a079c0b5',
#    'content': ['Hello there!\r\n\r\nHow can I help you on this fine morning?']},
#   {'id': 'rc_e5a9f187a079ceb2',
#    'content': ['Good morning! Do you have any questions today that I can assist you with? ']},
#   {'id': 'rc_e5a9f187a079ccaf',
#    'content': ['Hi! Good morning to you too! How can I help you today?']}],
#  'links': [],
#  'images': set(),
#  'code': None}

# %%
type(bard.get_answer("What is GDG TRIVANDRUM"))
# Out:
# dict

# %%
x = bard.get_answer("What is GDG TRIVANDRUM")['content']

# %%
x
# Out:
# "GDG Trivandrum, or Google Developer Group Trivandrum, is a community of developers in and around Trivandrum, India. The group was founded in 2011 and has since grown to over 800 members. GDG Trivandrum hosts a variety of events throughout the year, including meetups, workshops, and conferences. The group's goal is to provide developers with opportunities to learn, collaborate, and grow.\n\nSome of the events that GDG Trivandrum has hosted in the past include:\n\n* **Meetups:** Meetups are held on a monthly basis and are open to all developers. Topics covered at meetups range from beginner-level to advanced topics.\n* **Workshops:** Workshops are held on a bi-monthly basis and provide hands-on training on specific topics.\n* **Conferences:** Conferences are held on an annual basis and bring together developers from all over the world.\n\nIn addition to hosting events, GDG Trivandrum also provides a number of resources to its members. These resources include:\n\n* **A website:** The G
# ...

# %%
from gtts import gTTS #Import Google Text to Speech
from IPython.display import Audio #Import Audio method from IPython's Display Class
x="Hi I am Google Bard API...." + x
tts = gTTS(x) #Provide the string to convert to speech
tts.save('1.wav') #save the string converted to speech as a .wav file
sound_file = '1.wav'
Audio(sound_file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
